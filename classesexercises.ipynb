# %%
class DemoPlainClass:
 a: int 
 b: float = 1.1 
 c = 'spam'

# %%
 DemoPlainClass.__annotations__
# Out:
# {'a': int, 'b': float}

# %%
DemoPlainClass.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15036/1944608959.py in <module>
# ----> 1 DemoPlainClass.a
#
# AttributeError: type object 'DemoPlainClass' has no attribute 'a'

# %%
DemoPlainClass.b
# Out:
# 1.1

# %%
DemoPlainClass.c
# Out:
# 'spam'

# %%
import typing
class DemoNTClass(typing.NamedTuple):
    a: int 
    b: float = 1.1 
    c = 'spam'

# %%
DemoNTClass.__annotations__
# Out:
# {'a': int, 'b': float}

# %%
DemoNTClass.b
# Out:
# _tuplegetter(1, 'Alias for field number 1')

# %%
DemoNTClass.c
# Out:
# 'spam'

# %%
DemoNTClass.__doc__
# Out:
# 'DemoNTClass(a, b)'

# %%
nt = DemoNTClass(8)

# %%
nt.a
# Out:
# 8

# %%
nt.b
# Out:
# 1.1

# %%
nt.c
# Out:
# 'spam'

# %%
from dataclasses import dataclass

# %%
class DemoDataClass:
 a: int 
 b: float = 1.1 
 c = 'spam'

# %%
DemoDataClass.__annotations__
# Out:
# {'a': int, 'b': float}

# %%
DemoDataClass.__doc__

# %%
dc.b
# Out:
# 'oops'

# %%
dc.c
# Out:
# 'whatever'

# %%
dc.a
# Out:
# 10

# %%
dc.a = 10

# %%
dc.b = 'oops'

# %%
 dc.c = 'whatever'

# %%
DemoDataClass
# Out:
# __main__.DemoDataClass

# %%
dc.a
# Out:
# 10

# %%
dc.b
# Out:
# 'oops'

# %%
dc.c
# Out:
# 'whatever'
