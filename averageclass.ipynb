# %%
class Averager():
    def __init__(self):
        self.series=[]
    def __call__(self,new_value):
        self.series.append(new_value)
        total=sum(self.series)
        return total/len(self.series)

# %%
avg = Averager()

# %%
avg(10)
# Out:
# 10.0

# %%
avg(12)
# Out:
# 11.0

# %%
class Gizmo:
    def __init__(self):
        print('Gizmo id: %d' % id(self))

# %%
 x = Gizmo()
# Out:
# Gizmo id: 1661307747824
